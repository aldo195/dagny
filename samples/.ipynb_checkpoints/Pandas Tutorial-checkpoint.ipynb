# %%
import pandas as pd
df = pd.read_csv("~/repos/dagny/samples/va-nayax-092617.csv")
df
# Out:
#                           Scan Results 09/26/2017 at 11:58:26 (GMT+0300)  \
# 0                            Nayax LTD              Roul Walenberg 18 st
# 1                            Gal Bayer                          nayax-gb
# 2                                  NaN                               NaN
# 3                          Launch Date                      Active Hosts
# 4    09/26/2017 at 11:12:35 (GMT+0300)                                 3
# 5                                  NaN                               NaN
# 6                                   IP                               DNS
# 7                           10.0.0.182            oren-new.nayaxvend.int
# 8                           10.0.0.182            oren-new.nayaxvend.int
# 9                           10.0.0.182            oren-new.nayaxvend.int
# 10                          10.0.0.182            oren-new.nayaxvend.int
# 11                          10.0.0.182            oren-new.nayaxvend.int
# ...

# %%
df[df['Unnamed: 8'] == '5']
# Out:
#    Scan Results 09/26/2017 at 11:58:26 (GMT+0300) Unnamed: 2      Unnamed: 3  \
# 87   10.0.0.181                nati.nayaxvend.int       NATI  Windows 10 Pro
#
#                   Unnamed: 4 Unnamed: 5                       Unnamed: 6  \
# 87  host scanned, found vuln       5005  NetBIOS Brute Force of Accounts
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9         ...         Unnamed: 15  \
# 87       Vuln          5        NaN         ...                 NaN
#
#                                           Unnamed: 16  \
# 87  User access (login and password) was obtained ...
#
#                                           Unnamed: 17  \
# 87  Unauthorized users can penetrate your shared f...
#
#                                           Unnamed: 18  \
# 87  Please change the user password or disable it ...
#
#                                           Unnamed: 19 Unnamed: 20  \
# 87  Source: Metasploit\r\nReference:CVE-1999-0506\...         NaN
#
# ...

# %%
df['Unnamed: 8'].str.contains('1')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      False
# 4      False
# 5        NaN
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 325     True
# 326     True
# 327     True
# 328     True
# 329     True
# 330     True
# 331     True
# 332     True
# 333     True
# 334     True
# 335     True
# 336     True
# 337     True
# 338     True
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# 344     True
# 345     True
# 346     True
# 347     True
# 348     True
# 349     True
# 350     True
# 351     True
# 352     True
# 353     True
# 354      NaN
# Name: Unnamed: 8, Length: 355, dtype: object

# %%
df['Unnamed: 8'].value_counts()
# Out:
# 2             170
# 1             143
# 3              33
# 2nd Scan        1
# Severity        1
# Scan Title      1
# 5               1
# Name: Unnamed: 8, dtype: int64

# %%
df['Unnamed: 8'].value_counts().sort_index().plot()

# %%
# %matplotlib inline
df['Unnamed: 8'].value_counts().sort_index().plot()

# %%
df[['Scan Results', 'Unnamed: 8']]
# Out:
#                           Scan Results  Unnamed: 8
# 0                            Nayax LTD         NaN
# 1                            Gal Bayer         NaN
# 2                                  NaN         NaN
# 3                          Launch Date  Scan Title
# 4    09/26/2017 at 11:12:35 (GMT+0300)    2nd Scan
# 5                                  NaN         NaN
# 6                                   IP    Severity
# 7                           10.0.0.182           3
# 8                           10.0.0.182           3
# 9                           10.0.0.182           3
# 10                          10.0.0.182           3
# 11                          10.0.0.182           3
# 12                          10.0.0.182           3
# 13                          10.0.0.182           2
# 14                          10.0.0.182           2
# 15                          10.0.0.182           3
# 16                          10.0.0.182           2
# ...
